# %%
from IPython.display import FileLink

# إنشاء ملف .ipynb يحتوي على الخطوات كلها
notebook_content = {
    "cells": [
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "# مشروع Java باستخدام Gradle في Google Colab\n",
                "## Refactoring Lab - خطوات كاملة خطوة بخطوة"
            ]
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "# الخطوة 1: تثبيت Gradle\n",
                "!wget https://services.gradle.org/distributions/gradle-8.6-bin.zip\n",
                "!unzip -q gradle-8.6-bin.zip -d /opt/\n",
                "import os\n",
                "os.environ[\"PATH\"] += \":/opt/gradle-8.6/bin\""
            ]
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "# الخطوة 2: إنشاء مشروع Gradle جديد\n",
                "!gradle init --type java-application --dsl groovy --project-name RefactoringLab --package com.example --test-framework junit-jupiter --no-split-project --no-build-cache --warning-mode all"
            ]
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "# الخطوة 3: الدخول إلى مجلد المشروع\n",
                "%cd RefactoringLab"
            ]
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "# الخطوة 4: إنشاء كود Calculator.java قبل إعادة التسمية\n",
                "code = \"\"\"\n",
                "package com.example;\n",
                "\n",
                "public class Calculator {\n",
                "    public double calc(double a, double b) {\n",
                "        double x = a + b;\n",
                "        double y = a * b;\n",
                "        return x / y;\n",
                "    }\n",
                "\n",
                "    public void prtRes(double res) {\n",
                "        System.out.println(\"Result: \" + res);\n",
                "    }\n",
                "}\n",
                "\"\"\"\n",
                "with open(\"src/main/java/com/example/Calculator.java\", \"w\") as f:\n",
                "    f.write(code)"
            ]
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "# الخطوة 5: إنشاء اختبار CalculatorTest.java\n",
                "import os\n",
                "os.makedirs(\"src/test/java/com/example\", exist_ok=True)\n",
                "\n",
                "test_code = \"\"\"\n",
                "package com.example;\n",
                "\n",
                "import org.junit.jupiter.api.Test;\n",
                "import static org.junit.jupiter.api.Assertions.*;\n",
                "\n",
                "public class CalculatorTest {\n",
                "\n",
                "    @Test\n",
                "    public void testCalc() {\n",
                "        Calculator calc = new Calculator();\n",
                "        double result = calc.calc(4, 2);\n",
                "        assertEquals(0.75, result, 0.0001);\n",
                "    }\n",
                "}\n",
                "\"\"\"\n",
                "with open(\"src/test/java/com/example/CalculatorTest.java\", \"w\") as f:\n",
                "    f.write(test_code)"
            ]
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "# الخطوة 6: تشغيل اختبار JUnit\n",
                "!./gradlew test"
            ]
        }
    ],
    "metadata": {
        "colab": {
            "name": "RefactoringLab_Java_Gradle.ipynb",
        },
        "kernelspec": {
            "display_name": "Python 3",
            "language": "python",
            "name": "python3"
        },
        "language_info": {
            "name": "python"
        }
    },
    "nbformat": 4,
    "nbformat_minor": 0
}

# حفظ الملف
import json
notebook_path = "/mnt/data/RefactoringLab_Java_Gradle.ipynb"
with open(notebook_path, "w") as f:
    json.dump(notebook_content, f)

FileLink(notebook_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-00c07d2c866d> in <cell line: 0>()
#     132 import json
#     133 notebook_path = "/mnt/data/RefactoringLab_Java_Gradle.ipynb"
# --> 134 with open(notebook_path, "w") as f:
#     135     json.dump(notebook_content, f)
#     136
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/data/RefactoringLab_Java_Gradle.ipynb'
